# %% [markdown]
# ## INFORME ANALISIS ESTADISTICA - GEPOL

# %% [markdown]
# 1. Importar las librerías o APIs necesarias para el procesamiento de datos.

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. Leer los datos necesarios para graficarlos

# %%
df = pd.read_json('C:/Users/wagne/Downloads/ANALISIS-ESTADISTICA-GEPOL/data/gepol.json')
df.head(100)
# Out:
#         Mes  Dia  Cantidad  NoMes
# 0     ENERO   31       384      1
# 1     ENERO   19       351      1
# 2     ENERO    4       410      1
# 3     ENERO   26       415      1
# 4     ENERO   10       273      1
# 5     ENERO   17       352      1
# 6   FEBRERO    2       436      2
# 7   FEBRERO   16       420      2
# 8     ENERO   27       466      1
# 9     ENERO    1       120      1
# 10    ENERO    2       329      1
# 11    ENERO    5       270      1
# 12    ENERO   12       291      1
# 13  FEBRERO   18        43      2
# 14  FEBRERO    1       357      2
# 15    ENERO   23       366      1
# 16    ENERO   30       336      1
# 17    ENERO   22       250      1
# 18    ENERO    3       323      1
# 19    ENERO   13       275      1
# 20  FEBRERO    7       431      2
# 21    ENERO   21       283      1
# 22    ENERO   20       429      1
# 23    ENERO   25       480      1
# 24    ENERO   11       292      1
# 25  FEBRERO    9       438      2
# ...

# %% [markdown]
# 3. Ordenar los datos adecuadamente de una forma ascendente

# %%
#organization by month o sea, organizacion por mes
by_month = df.sort_values('Mes')
by_month.head(10)
# Out:
#       Mes  Dia  Cantidad  NoMes
# 0   ENERO   31       384      1
# 21  ENERO   21       283      1
# 22  ENERO   20       429      1
# 23  ENERO   25       480      1
# 29  ENERO   24       422      1
# 30  ENERO   29       267      1
# 31  ENERO   14       298      1
# 19  ENERO   13       275      1
# 32  ENERO   15       240      1
# 36  ENERO    8       180      1

# %% [markdown]
# 4. Graficar los datos con la librería Seaborn

# %%
sns.catplot(x = "Mes", data = df, kind = "count");
plt.title('CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023') # Título del gráfico.
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')

# %% [markdown]
# 5. Los datos graficados anteriormente, estan sin tanta información para su análisis, por lo cual, se pondrán leyendas en las barras que muestran los datos analizados.

# %%
groupedvalues = df.groupby('Mes').sum().reset_index()
g = sns.barplot(x = 'Mes', y = 'Cantidad', data = groupedvalues)
for index, row in groupedvalues.iterrows():
    g.text(row.name, row.Cantidad - 2, round(row.Cantidad, 2), color = 'red', ha = "center")

plt.title('CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')

# %% [markdown]
# 6. Graficar un histograma

# %%
#histograma
sns.histplot(data=df, x="Cantidad", kde=True)
plt.title('CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')

# %% [markdown]
# 7. Crear una gráfica de dispersión

# %%
sns.stripplot(data=df, x="Cantidad", y="Mes")
plt.title('CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')

# %% [markdown]
# 8. Crear una gráfica de violín

# %%
sns.violinplot(data=df, x="Cantidad", y="Mes")
plt.title('CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')

# %% [markdown]
# 7. gráfica tipo parcela (PairPlot)

# %%
#graficar varios graficos o parcelas

sns.pairplot(df,height=1.5)

# %% [markdown]
# 8. Gráfica tipo mixta (violín + dispersión)

# %%
sns.catplot(data=df, x="Cantidad", y="Mes", kind="violin", color=".9", inner=None)
sns.swarmplot(data=df, x="Cantidad", y="Mes", size=3)
plt.title('CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')

# %% [markdown]
# 9. Gráficas de tipo dispersión, segmentando datos.

# %%
sns.relplot(data=df, x="Cantidad", y="Mes", hue="Mes")
plt.title('CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')

# %% [markdown]
# 10. Gráfica tipo linea, para exponer la cronología de producción documental

# %%
sns.relplot(data=df, kind="line")
plt.title('CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE DOCUMENTOS PRODUCIDOS EN EL GEPOL MES 01 Y 02 - 2023')

# %% [markdown]
# 11. Referencias bibliográficas

# %% [markdown]
# * Count plot | Interactive Chaos. (s. f.). https://interactivechaos.com/es/manual/tutorial-de-seaborn/count-plot
#
# * McKinney, W. (2017). Python for Data Analysis: Data Wrangling with Pandas, Numpy, and Ipython. O’Reilly Media.
#
# * Torres, A. (2021, 9 diciembre). Limpieza de datos en Pandas: Explicado con ejemplos. freeCodeCamp.org. https://www.freecodecamp.org/espanol/news/limpieza-de-datos-en-pandas-explicado-con-ejemplos/
#
# * Roldán, M. M. R. C. (2022). BIG DATA con PYTHON. Recolección, almacenamiento y proceso. Rc Libros.
